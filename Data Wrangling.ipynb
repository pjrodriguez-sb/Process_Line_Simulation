# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from six.moves import urllib
import zipfile
from scipy import stats

# %%
cyc = pd.read_csv(r'/Users/pedrorodriguez/Desktop/Springboard/Capstone Project/Second Part/Cycle_time_per_station')
dtf = pd.read_csv(r'/Users/pedrorodriguez/Desktop/Springboard/Capstone Project/Second Part/Downtime_freq')
dtt = pd.read_csv(r'/Users/pedrorodriguez/Desktop/Springboard/Capstone Project/Second Part/Downtime_time')

# %%
cyc.head()
# Out:
#    Unnamed: 0  station  production_line      Sample  Cycle_time
# 0           0      1.0              1.0  Unnamed: 6   96.200000
# 1           1      2.0              1.0  Unnamed: 6   22.200000
# 2           2      3.0              2.0  Unnamed: 6    7.250000
# 3           3      4.0              2.0  Unnamed: 6   11.666667
# 4           4      5.0              2.0  Unnamed: 6   75.250000

# %%
cyc['Ct_min'] = cyc['Cycle_time']/60
cyc.head()
# Out:
#    Unnamed: 0  station  production_line      Sample  Cycle_time    Ct_min
# 0           0      1.0              1.0  Unnamed: 6   96.200000  1.603333
# 1           1      2.0              1.0  Unnamed: 6   22.200000  0.370000
# 2           2      3.0              2.0  Unnamed: 6    7.250000  0.120833
# 3           3      4.0              2.0  Unnamed: 6   11.666667  0.194444
# 4           4      5.0              2.0  Unnamed: 6   75.250000  1.254167

# %%
cyc['Ct_hr'] = cyc['Ct_min']/60
cyc.head()
# Out:
#    Unnamed: 0  station  production_line      Sample  Cycle_time    Ct_min  \
# 0           0      1.0              1.0  Unnamed: 6   96.200000  1.603333
# 1           1      2.0              1.0  Unnamed: 6   22.200000  0.370000
# 2           2      3.0              2.0  Unnamed: 6    7.250000  0.120833
# 3           3      4.0              2.0  Unnamed: 6   11.666667  0.194444
# 4           4      5.0              2.0  Unnamed: 6   75.250000  1.254167
#
#       Ct_hr
# 0  0.026722
# 1  0.006167
# 2  0.002014
# 3  0.003241
# 4  0.020903

# %%
dtf.head()
# Out:
#    Unnamed: 0    station  station_no.        Date  Downtime  Year
# 0           0  station 1            1  2018-01-01         8  2018
# 1           1  station 2            2  2018-01-01         8  2018
# 2           2  station 3            3  2018-01-01         4  2018
# 3           3  station 4            4  2018-01-01         7  2018
# 4           4  station 5            5  2018-01-01         6  2018

# %%
dtt.head()
# Out:
#    Unnamed: 0    station  station_no.  variable  value
# 0           0  station 1            1  sample 1   2942
# 1           1  station 2            2  sample 1    605
# 2           2  station 3            3  sample 1    717
# 3           3  station 4            4  sample 1   1014
# 4           4  station 5            5  sample 1   1743

# %%
dtt['dt_min'] = dtt['value']/60
dtt.head()
# Out:
#    Unnamed: 0    station  station_no.  variable  value     dt_min
# 0           0  station 1            1  sample 1   2942  49.033333
# 1           1  station 2            2  sample 1    605  10.083333
# 2           2  station 3            3  sample 1    717  11.950000
# 3           3  station 4            4  sample 1   1014  16.900000
# 4           4  station 5            5  sample 1   1743  29.050000

# %%
dtt['dt_hr'] = dtt['dt_min']/60
dtt.head()
# Out:
#    Unnamed: 0    station  station_no.  variable  value     dt_min     dt_hr
# 0           0  station 1            1  sample 1   2942  49.033333  0.817222
# 1           1  station 2            2  sample 1    605  10.083333  0.168056
# 2           2  station 3            3  sample 1    717  11.950000  0.199167
# 3           3  station 4            4  sample 1   1014  16.900000  0.281667
# 4           4  station 5            5  sample 1   1743  29.050000  0.484167

# %%
cyc.shape
# Out:
# (5200, 7)

# %%
dtf.shape
# Out:
# (1248, 6)

# %%
dtt.shape
# Out:
# (5200, 7)

# %% [markdown]
# ## Distribution of Cycle Time per station

# %%
#For Cycle time
plt.hist(cyc['Ct_min'])
plt.show()

# %% [markdown]
# ## Distribution of Downtime Freq

# %%
from scipy.stats import norm

# %%
#For Downtime freq
plt.hist(dtf['Downtime'])
plt.show()

# %% [markdown]
# ## Distribution of Downtime times

# %%
plt.hist(dtt['dt_min'], bins=50)
plt.show()

# %% [markdown]
# # Kolmogorov–Smirnov test and check the goodness of fit:

# %%
#For the downtime times
dist = getattr(stats, 'norm')
parameters = dist.fit(dtt['dt_min'])
print(parameters)
# Out:
# (24.11834294871795, 11.90926796586648)

# %%
stats.kstest(dtt['dt_min'], "norm", parameters)
# Out:
# KstestResult(statistic=0.10976443402036751, pvalue=5.093714208817535e-55)

# %% [markdown]
# Since the downtime times contains more than 50 data points each one. We want a significance level (α) of 0.05 , so we look at the last row of the third column. The critical value is 1.36, which is more than our test statistic (0.10976443402036751). So we can say with 95% confidence that the our data comes from a normal distribution.

# %%
#For Cycle Time
dist = getattr(stats, 'norm')
parameters = dist.fit(cyc['Ct_min'])
print(parameters)
# Out:
# (0.6905975819215512, 0.5272520850307967)

# %%
stats.kstest(cyc['Ct_min'], "norm", parameters)
# Out:
# KstestResult(statistic=0.14468839619988116, pvalue=1.8321440327897125e-95)

# %% [markdown]
# Since the Cycle time contains more than 50 data points each one. We want a significance level (α) of 0.05 , so we look at the last row of the third column. The critical value is 1.36, which is more than our test statistic (0.14468839619988116). So we can say with 95% confidence that the our data comes from a normal distribution.

# %%
#For Downtime freq
dist = getattr(stats, 'norm')
parameters = dist.fit(dtf['Downtime'])
print(parameters)
# Out:
# (5.919070512820513, 2.745746436768687)

# %%
stats.kstest(dtf['Downtime'], "norm", parameters)
# Out:
# KstestResult(statistic=0.17515431607270726, pvalue=5.878933010146392e-34)

# %% [markdown]
# Since the downtime freq contains more than 50 data points each one. We want a significance level (α) of 0.05 , so we look at the last row of the third column. The critical value is 1.36, which is more than our test statistic (0.17515431607270726). So we can say with 95% confidence that the our data comes from a normal distribution.

# %%
#Cycle time test
list_of_dists = ['alpha','anglit','arcsine','beta','betaprime','bradford','burr','burr12','cauchy','chi','chi2','cosine','dgamma','dweibull','erlang','expon','exponnorm','exponweib','exponpow','f','fatiguelife','fisk','foldcauchy','foldnorm','frechet_r','frechet_l','genlogistic','genpareto','gennorm','genexpon','genextreme','gausshyper','gamma','gengamma','genhalflogistic','gilbrat','gompertz','gumbel_r','gumbel_l','halfcauchy','halflogistic','halfnorm','halfgennorm','hypsecant','invgamma','invgauss','invweibull','johnsonsb','johnsonsu','kstwobign','laplace','levy','levy_l','logistic','loggamma','loglaplace','lognorm','lomax','maxwell','mielke','nakagami','ncx2','ncf','nct','norm','pareto','pearson3','powerlaw','powerlognorm','powernorm','rdist','reciprocal','rayleigh','rice','recipinvgauss','semicircular','t','triang','truncexpon','truncnorm','tukeylambda','uniform','vonmises','vonmises_line','wald','weibull_min','weibull_max']

results = []
for i in list_of_dists:
    dist = getattr(stats, i)
    param = dist.fit(cyc['Ct_min'])
    a = stats.kstest(cyc['Ct_min'], i, args=param)
    results.append((i,a[0],a[1]))
    
    
results.sort(key=lambda x:float(x[2]), reverse=True)
for j in results:
    print("{}: statistic={}, pvalue={}".format(j[0], j[1], j[2]))
# Out:
# genexpon: statistic=0.03860209841222706, pvalue=3.6101689178003855e-07
# pearson3: statistic=0.03984987474561077, pvalue=1.3023970830905538e-07
# gamma: statistic=0.039851940513724864, pvalue=1.300165608722756e-07
# chi2: statistic=0.03985559655588027, pvalue=1.2962253803849576e-07
# ncx2: statistic=0.039856151692833346, pvalue=1.295628105887378e-07
# recipinvgauss: statistic=0.04012731748441517, pvalue=1.0336542565946582e-07
# gengamma: statistic=0.041909583428624275, pvalue=2.2542581543835572e-08
# fatiguelife: statistic=0.0419519664547805, pvalue=2.1723304041084466e-08
# beta: statistic=0.04196242482213374, pvalue=2.1525639095109893e-08
# exponweib: statistic=0.04268700278848206, pvalue=1.136336297112129e-08
# powerlognorm: statistic=0.04294085521960217, pvalue=9.06106787453932e-09
# f: statistic=0.0430246481676666, pvalue=8.40610537917768e-09
# exponnorm: statistic=0.04371663318508684, pvalue=4.498545074059636e-09
# burr12: statistic=0.0441025719985044, pvalue=3.1604780685559566e-09
# johnsonsb: statistic=0.045273070798159676, pvalue=1.0629353397712945e-09
# invgauss: statistic=0.047615716757047344, pvalue=1.1017269690203954e-10
# johnsonsu: statistic=0.049366602121660774, pvalue=1.8786416362247502e-11
# lognorm: statistic=0.049498514259502746, pvalue=1.6399854443475417e-11
# mielke: statistic=0.049970417727406596, pvalue=1.0056981385876701e-11
# burr: statistic=0.049972768792496264, pvalue=1.0032392983230572e-11
# ncf: statistic=0.051474728429407424, pvalue=2.0511869688895568e-12
# betaprime: statistic=0.05282908056210553, pvalue=4.707866705685821e-13
# frechet_r: statistic=0.056089564561074536, pvalue=1.16368097952205e-14
# weibull_min: statistic=0.056089564561074536, pvalue=1.16368097952205e-14
# invgamma: statistic=0.05759824169407657, pvalue=1.9481553481543074e-15
# nct: statistic=0.05890536460996004, pvalue=3.984880391298055e-16
# invweibull: statistic=0.05967606174165291, pvalue=1.5373859128476334e-16
# genextreme: statistic=0.05968943813136396, pvalue=1.5120153800316516e-16
# fisk: statistic=0.05986097984545402, pvalue=1.221056161545889e-16
# wald: statistic=0.06202138459794532, pvalue=7.850247275611542e-18
# gausshyper: statistic=0.062154924887889096, pvalue=6.604216253168733e-18
# alpha: statistic=0.06508178417079002, pvalue=1.3613907110359448e-19
# halflogistic: statistic=0.0683835154959623, pvalue=1.3766078203381074e-21
# gilbrat: statistic=0.07089767450859452, pvalue=3.5735573859111334e-23
# genhalflogistic: statistic=0.07327677144247519, pvalue=9.991790584511354e-25
# foldcauchy: statistic=0.07511819625889726, pvalue=5.779786187760692e-26
# genlogistic: statistic=0.07717142801665297, pvalue=2.215241604832404e-27
# gumbel_r: statistic=0.0781736338855544, pvalue=4.365920674574414e-28
# nakagami: statistic=0.08642469598523128, pvalue=3.056278238202199e-34
# halfgennorm: statistic=0.08668582277803072, pvalue=1.90665154190101e-34
# kstwobign: statistic=0.09216020865903063, pvalue=6.932560740268813e-39
# loglaplace: statistic=0.09329914886607227, pvalue=7.636411181365389e-40
# halfnorm: statistic=0.09580158076429202, pvalue=5.4495220979914544e-42
# foldnorm: statistic=0.09580872942195517, pvalue=5.372104404224826e-42
# gompertz: statistic=0.09861611186289904, pvalue=1.7934456564404412e-44
# genpareto: statistic=0.09995815437329597, pvalue=1.1075509229162975e-45
# exponpow: statistic=0.10356717287812037, pvalue=5.1338224748421444e-49
# expon: statistic=0.10988953347749902, pvalue=3.821377559068833e-55
# lomax: statistic=0.11888371606638617, pvalue=1.7047854612637218e-64
# t: statistic=0.12401245975159339, pvalue=3.6848757442866705e-70
# logistic: statistic=0.12646799631222885, pvalue=5.863694308519783e-73
# vonmises_line: statistic=0.12668538227972065, pvalue=3.294309031519758e-73
# frechet_l: statistic=0.12797671152076806, pvalue=1.0502407826658743e-74
# weibull_max: statistic=0.12797671152076806, pvalue=1.0502407826658743e-74
# tukeylambda: statistic=0.12837756149530333, pvalue=3.5778857366944245e-75
# hypsecant: statistic=0.13267996622143624, pvalue=2.7581708144622917e-80
# maxwell: statistic=0.13287382100664946, pvalue=1.6077317058542474e-80
# dweibull: statistic=0.1356470677495203, pvalue=6.52762111191589e-84
# gennorm: statistic=0.1359929508795485, pvalue=2.4365418363523562e-84
# laplace: statistic=0.13697744841985407, pvalue=1.453894734246191e-85
# rice: statistic=0.13844429334617064, pvalue=2.0981005262282182e-87
# rayleigh: statistic=0.13847426802850027, pvalue=1.9231090135021762e-87
# halfcauchy: statistic=0.1436188734793986, pvalue=4.6667395747091586e-94
# norm: statistic=0.14468839619988116, pvalue=1.8321440327897125e-95
# truncnorm: statistic=0.14468841904196167, pvalue=1.8320168740730518e-95
# chi: statistic=0.14499506152251607, pvalue=7.208414028122228e-96
# dgamma: statistic=0.14724237918172134, pvalue=7.2835941800501534e-99
# erlang: statistic=0.15334297231451044, pvalue=3.117171466064342e-107
# pareto: statistic=0.15441249108047428, pvalue=9.792652375055245e-109
# loggamma: statistic=0.1569766666729523, pvalue=2.209598402655254e-112
# reciprocal: statistic=0.16016158201301595, pvalue=5.363381840210553e-117
# cauchy: statistic=0.1651846553337532, pvalue=1.8123931950770586e-124
# anglit: statistic=0.2908804538187608, pvalue=0.0
# arcsine: statistic=0.5175811105310484, pvalue=0.0
# bradford: statistic=0.38475661857070653, pvalue=0.0
# cosine: statistic=0.3186304203913655, pvalue=0.0
# gumbel_l: statistic=0.29605841723885556, pvalue=0.0
# levy: statistic=0.2947184348204599, pvalue=0.0
# levy_l: statistic=0.5874038007243308, pvalue=0.0
# powerlaw: statistic=0.3178408394318205, pvalue=0.0
# powernorm: statistic=1.0, pvalue=0.0
# rdist: statistic=0.3969689634289547, pvalue=0.0
# semicircular: statistic=0.3696390169039451, pvalue=0.0
# triang: statistic=0.366399200666554, pvalue=0.0
# truncexpon: statistic=0.3551093589859957, pvalue=0.0
# uniform: statistic=0.5667656686242419, pvalue=0.0
# vonmises: statistic=1.353018682567332e+30, pvalue=0.0

# %% [markdown]
# #### It seems the best fitted distribution of Cycle time is genexpon distribution.

# %%
import plotly.express as px

# %%
import seaborn as sns

sns.distplot(cyc['Ct_min'])

# %%
# Downtime time test
list_of_dists = ['alpha','anglit','arcsine','beta','betaprime','bradford','burr','burr12','cauchy','chi','chi2','cosine','dgamma','dweibull','erlang','expon','exponnorm','exponweib','exponpow','f','fatiguelife','fisk','foldcauchy','foldnorm','frechet_r','frechet_l','genlogistic','genpareto','gennorm','genexpon','genextreme','gausshyper','gamma','gengamma','genhalflogistic','gilbrat','gompertz','gumbel_r','gumbel_l','halfcauchy','halflogistic','halfnorm','halfgennorm','hypsecant','invgamma','invgauss','invweibull','johnsonsb','johnsonsu','kstwobign','laplace','levy','levy_l','logistic','loggamma','loglaplace','lognorm','lomax','maxwell','mielke','nakagami','ncx2','ncf','nct','norm','pareto','pearson3','powerlaw','powerlognorm','powernorm','rdist','reciprocal','rayleigh','rice','recipinvgauss','semicircular','t','triang','truncexpon','truncnorm','tukeylambda','uniform','vonmises','vonmises_line','wald','weibull_min','weibull_max']

results = []
for i in list_of_dists:
    dist = getattr(stats, i)
    param = dist.fit(dtt['dt_min'])
    a = stats.kstest(dtt['dt_min'], i, args=param)
    results.append((i,a[0],a[1]))
    
    
results.sort(key=lambda x:float(x[2]), reverse=True)
for j in results:
    print("{}: statistic={}, pvalue={}".format(j[0], j[1], j[2]))
# Out:
# genexpon: statistic=0.031207439684734495, pvalue=7.80603305712944e-05
# erlang: statistic=0.03673817027974091, pvalue=1.5585157884368391e-06
# chi2: statistic=0.036739422388088916, pvalue=1.5570231505290165e-06
# pearson3: statistic=0.036739960613338396, pvalue=1.5563819561804434e-06
# gamma: statistic=0.03674020219220253, pvalue=1.5560942431216786e-06
# ncx2: statistic=0.036746782948415324, pvalue=1.5482764639926078e-06
# f: statistic=0.036967270882723946, pvalue=1.3071751352835429e-06
# johnsonsb: statistic=0.03729367898688851, pvalue=1.015536632888294e-06
# recipinvgauss: statistic=0.038510867177725894, pvalue=3.884622813139238e-07
# fatiguelife: statistic=0.039275951364323713, pvalue=2.0900435451787771e-07
# invgauss: statistic=0.04059907907119009, pvalue=6.952008812042805e-08
# gengamma: statistic=0.041692774678707356, pvalue=2.7226665913473204e-08
# lognorm: statistic=0.04221607114832704, pvalue=1.7233471249096922e-08
# exponweib: statistic=0.04243455741231411, pvalue=1.421381621532876e-08
# johnsonsu: statistic=0.04274813793796439, pvalue=1.0761679698036812e-08
# exponnorm: statistic=0.042926258778186566, pvalue=9.180133518607801e-09
# fisk: statistic=0.043573567468983, pvalue=5.123469185986485e-09
# ncf: statistic=0.04519690092279094, pvalue=1.142038313973178e-09
# invgamma: statistic=0.04546601000343253, pvalue=8.857435954884054e-10
# gausshyper: statistic=0.04666815677437802, pvalue=2.794138163034589e-10
# mielke: statistic=0.04676771827586845, pvalue=2.5360813741290004e-10
# burr: statistic=0.047995334903943365, pvalue=7.548638845684022e-11
# alpha: statistic=0.04855092536430172, pvalue=4.3170970653951003e-11
# genextreme: statistic=0.04857674808641266, pvalue=4.2057617143937474e-11
# invweibull: statistic=0.04857702321976198, pvalue=4.204590747143334e-11
# powerlognorm: statistic=0.049033542279673825, pvalue=2.6431329958457834e-11
# betaprime: statistic=0.049383011720504744, pvalue=1.8471942223722017e-11
# burr12: statistic=0.049558425075280355, pvalue=1.541664846836103e-11
# beta: statistic=0.049567967014542025, pvalue=1.5265484363012587e-11
# nct: statistic=0.051756999209975785, pvalue=1.514120341670505e-12
# frechet_r: statistic=0.05274094642093885, pvalue=5.187099625081935e-13
# weibull_min: statistic=0.05274094642093885, pvalue=5.187099625081935e-13
# genlogistic: statistic=0.0613040904603846, pvalue=1.973780101163703e-17
# gumbel_r: statistic=0.06151954792208131, pvalue=1.4980098789021454e-17
# loglaplace: statistic=0.0652980642163623, pvalue=1.0146601830414187e-19
# nakagami: statistic=0.06547706699433009, pvalue=7.949511771681408e-20
# chi: statistic=0.06547749182656709, pvalue=7.944902737509224e-20
# kstwobign: statistic=0.06606409233517746, pvalue=3.554219754271365e-20
# logistic: statistic=0.08121864718519455, pvalue=2.759888950679776e-30
# genhalflogistic: statistic=0.08438297215186434, pvalue=1.1641461178566757e-32
# dgamma: statistic=0.08796807247660399, pvalue=1.84070948766713e-35
# wald: statistic=0.08907196817385876, pvalue=2.3927615910101788e-36
# hypsecant: statistic=0.09111332531845444, pvalue=5.14057966668928e-38
# dweibull: statistic=0.09669470710079886, pvalue=9.044604266528735e-43
# foldcauchy: statistic=0.09807255706603912, pvalue=5.480236354238539e-44
# rayleigh: statistic=0.09856559773004148, pvalue=1.990146125901628e-44
# rice: statistic=0.0985666550488355, pvalue=1.985816820841268e-44
# maxwell: statistic=0.10387469171164793, pvalue=2.6353939265516016e-49
# loggamma: statistic=0.10751524377327326, pvalue=8.444929234443964e-53
# t: statistic=0.10975667791517818, pvalue=5.1852331664759666e-55
# norm: statistic=0.10976443402036751, pvalue=5.093714208817535e-55
# laplace: statistic=0.10981545664907592, pvalue=4.530493020781378e-55
# vonmises_line: statistic=0.10992350648154176, pvalue=3.5342680841211874e-55
# gilbrat: statistic=0.1100423837028186, pvalue=2.688578472091942e-55
# rdist: statistic=0.1148122059775995, pvalue=3.6027641423737686e-60
# halfnorm: statistic=0.12081746316462927, pvalue=1.3307640783404285e-66
# genpareto: statistic=0.12435023082545227, pvalue=1.5304144914665483e-70
# triang: statistic=0.12554462881919254, pvalue=6.713330973905194e-72
# halflogistic: statistic=0.13416060473666433, pvalue=4.3795727249399935e-82
# cauchy: statistic=0.1471133952522533, pvalue=1.085278844806229e-98
# gennorm: statistic=0.14714663236469427, pvalue=9.793239600867486e-99
# foldnorm: statistic=0.14966133902760503, pvalue=3.850946853381051e-102
# gumbel_l: statistic=0.14972119642911103, pvalue=3.190015386728029e-102
# cosine: statistic=0.17553243253975648, pvalue=1.3216980284398678e-140
# expon: statistic=0.18305381423162997, pvalue=5.740641847285704e-153
# lomax: statistic=0.1832752168623371, pvalue=2.4376288898144787e-153
# halfcauchy: statistic=0.18530625325005323, pvalue=8.971285382877297e-157
# truncexpon: statistic=0.18946367035961573, pvalue=6.332832980643104e-164
# bradford: statistic=0.20434389145576065, pvalue=7.235163901613134e-191
# anglit: statistic=0.23724661428743843, pvalue=5.47564456026871e-258
# powerlaw: statistic=0.2406476021585474, pvalue=1.5902271633552792e-265
# halfgennorm: statistic=0.242415133320792, pvalue=1.7366530967031856e-269
# arcsine: statistic=0.34155253762461424, pvalue=0.0
# exponpow: statistic=0.6694926460301543, pvalue=0.0
# frechet_l: statistic=0.7940828625258662, pvalue=0.0
# gompertz: statistic=0.8747821327311657, pvalue=0.0
# levy: statistic=0.3577454645808804, pvalue=0.0
# levy_l: statistic=0.5579183815530776, pvalue=0.0
# pareto: statistic=0.32899685814866997, pvalue=0.0
# powernorm: statistic=0.9909615384615384, pvalue=0.0
# reciprocal: statistic=1.0, pvalue=0.0
# semicircular: statistic=0.5571277671285542, pvalue=0.0
# truncnorm: statistic=1.0, pvalue=0.0
# tukeylambda: statistic=0.32504016373557365, pvalue=0.0
# uniform: statistic=0.3196135180537984, pvalue=0.0
# vonmises: statistic=3.8144031258477823e+27, pvalue=0.0
# weibull_max: statistic=0.7940828625258662, pvalue=0.0

# %% [markdown]
# #### It seems the best fitted distribution of the time of downtime is genexpon distribution.

# %%
sns.distplot(dtt['dt_min'])

# %%
# Downtime freq test
list_of_dists = ['alpha','anglit','arcsine','beta','betaprime','bradford','burr','burr12','cauchy','chi','chi2','cosine','dgamma','dweibull','erlang','expon','exponnorm','exponweib','exponpow','f','fatiguelife','fisk','foldcauchy','foldnorm','frechet_r','frechet_l','genlogistic','genpareto','gennorm','genexpon','genextreme','gausshyper','gamma','gengamma','genhalflogistic','gilbrat','gompertz','gumbel_r','gumbel_l','halfcauchy','halflogistic','halfnorm','halfgennorm','hypsecant','invgamma','invgauss','invweibull','johnsonsb','johnsonsu','kstwobign','laplace','levy','levy_l','logistic','loggamma','loglaplace','lognorm','lomax','maxwell','mielke','nakagami','ncx2','ncf','nct','norm','pareto','pearson3','powerlaw','powerlognorm','powernorm','rdist','reciprocal','rayleigh','rice','recipinvgauss','semicircular','t','triang','truncexpon','truncnorm','tukeylambda','uniform','vonmises','vonmises_line','wald','weibull_min','weibull_max']

results = []
for i in list_of_dists:
    dist = getattr(stats, i)
    param = dist.fit(dtf['Downtime'])
    a = stats.kstest(dtf['Downtime'], i, args=param)
    results.append((i,a[0],a[1]))
    
    
results.sort(key=lambda x:float(x[2]), reverse=True)
for j in results:
    print("{}: statistic={}, pvalue={}".format(j[0], j[1], j[2]))
# Out:
# invgauss: statistic=0.09766756123672599, pvalue=8.170978129003563e-11
# fatiguelife: statistic=0.09814537238316234, pvalue=6.460953316146797e-11
# recipinvgauss: statistic=0.0986726720885413, pvalue=4.979378051922892e-11
# ncf: statistic=0.09938046529349798, pvalue=3.5024537866633245e-11
# johnsonsu: statistic=0.10045931720283896, pvalue=2.038666884628083e-11
# lognorm: statistic=0.10052208615520691, pvalue=1.975119770056554e-11
# exponnorm: statistic=0.10165765873179616, pvalue=1.1099195884337657e-11
# powerlognorm: statistic=0.10216722794207517, pvalue=8.551680827330485e-12
# betaprime: statistic=0.10294723215860313, pvalue=5.722790980088043e-12
# pearson3: statistic=0.10314400035489685, pvalue=5.1688090531074356e-12
# chi2: statistic=0.10314899906612424, pvalue=5.155444055596283e-12
# gamma: statistic=0.10314949244174831, pvalue=5.154126762658526e-12
# erlang: statistic=0.10315216902730129, pvalue=5.146986140938259e-12
# f: statistic=0.10328045509111172, pvalue=4.815890850651032e-12
# invgamma: statistic=0.10446180651651316, pvalue=2.6005240183998562e-12
# nct: statistic=0.10498655740870083, pvalue=1.973342986394839e-12
# johnsonsb: statistic=0.10616143416841478, pvalue=1.0584063616670443e-12
# invweibull: statistic=0.10721594037959042, pvalue=6.014982521996424e-13
# genextreme: statistic=0.10721970969888472, pvalue=6.002784267891243e-13
# beta: statistic=0.1093398565185753, pvalue=1.8945163902216697e-13
# mielke: statistic=0.10977120952646935, pvalue=1.4941197449270816e-13
# burr12: statistic=0.10983019106883041, pvalue=1.446286330688555e-13
# gausshyper: statistic=0.10986952794686189, pvalue=1.415224945079882e-13
# fisk: statistic=0.10987364606480599, pvalue=1.4120113588517928e-13
# burr: statistic=0.11009551136649026, pvalue=1.249086736862217e-13
# frechet_r: statistic=0.11010392249229062, pvalue=1.243288371939071e-13
# weibull_min: statistic=0.11010392249229062, pvalue=1.243288371939071e-13
# alpha: statistic=0.11041096099362191, pvalue=1.0488198980489623e-13
# genexpon: statistic=0.1109278162080145, pvalue=7.868294579677817e-14
# exponweib: statistic=0.11404461682977995, pvalue=1.3511134254795599e-14
# gengamma: statistic=0.11648071330727361, pvalue=3.293819967678895e-15
# dgamma: statistic=0.12083367568889847, pvalue=2.4532541189161575e-16
# gumbel_r: statistic=0.12083530198825848, pvalue=2.4508306283341815e-16
# genlogistic: statistic=0.12089544596520313, pvalue=2.3628441843947236e-16
# dweibull: statistic=0.12141939178160382, pvalue=1.717011875867179e-16
# ncx2: statistic=0.12156731954830302, pvalue=1.5686081740799473e-16
# hypsecant: statistic=0.12549727233789854, pvalue=1.3639895217908017e-17
# chi: statistic=0.12905971186720577, pvalue=1.3923618210092206e-18
# nakagami: statistic=0.129071129404014, pvalue=1.3820716992335142e-18
# kstwobign: statistic=0.13090450628175604, pvalue=4.1637201730783932e-19
# genhalflogistic: statistic=0.13579592251622374, pvalue=1.5589555296631792e-20
# foldcauchy: statistic=0.13593016344955539, pvalue=1.4221039344051095e-20
# gompertz: statistic=0.13866295215398994, pvalue=2.147413078471228e-21
# vonmises_line: statistic=0.13923140671094636, pvalue=1.4422716751948189e-21
# t: statistic=0.13999053009781803, pvalue=8.454236103493817e-22
# halfgennorm: statistic=0.14103281795241845, pvalue=4.0409426056638124e-22
# logistic: statistic=0.14326389775533743, pvalue=8.167790809786745e-23
# foldnorm: statistic=0.14434163063624755, pvalue=3.7386009355612104e-23
# laplace: statistic=0.1487162697744109, pvalue=1.4738809855943707e-24
# loglaplace: statistic=0.15404319337053207, pvalue=2.5165948476512557e-26
# halfnorm: statistic=0.15415337740574847, pvalue=2.30983294080415e-26
# cauchy: statistic=0.15419530734911271, pvalue=2.2356546383441323e-26
# semicircular: statistic=0.1583592851662079, pvalue=8.356312261591862e-28
# rice: statistic=0.1632046341541467, pvalue=1.6296681061779102e-29
# rayleigh: statistic=0.16320976148189836, pvalue=1.622788096771802e-29
# genpareto: statistic=0.1643288332239669, pvalue=6.424420762492088e-30
# tukeylambda: statistic=0.16826930512739302, pvalue=2.335506935785766e-31
# maxwell: statistic=0.16995685347139666, pvalue=5.510949936003908e-32
# norm: statistic=0.17515431607270726, pvalue=5.878933010146392e-34
# halflogistic: statistic=0.17773151780478252, pvalue=5.873127980304492e-35
# loggamma: statistic=0.17846869239767998, pvalue=3.019577667537594e-35
# wald: statistic=0.18688172503072847, pvalue=1.2455206611555173e-38
# gilbrat: statistic=0.18941126518435752, pvalue=1.1124320366389477e-39
# gumbel_l: statistic=0.1900498229122669, pvalue=6.0137049482370605e-40
# halfcauchy: statistic=0.19106336341942037, pvalue=2.255461049522913e-40
# exponpow: statistic=0.1948949738309893, pvalue=5.271895333998556e-42
# truncexpon: statistic=0.1969543309785998, pvalue=6.782207020095994e-43
# bradford: statistic=0.2068128872443532, pvalue=2.7128416889875295e-47
# triang: statistic=0.21372561218412583, pvalue=1.6460604852444836e-50
# lomax: statistic=0.21492907283074447, pvalue=4.4170320659254457e-51
# expon: statistic=0.2298278078314983, pvalue=1.9698280071681698e-58
# pareto: statistic=0.22983044490702503, pvalue=1.9637290443967932e-58
# cosine: statistic=0.2404857670183101, pvalue=5.232682578294393e-64
# gennorm: statistic=0.24999018551735896, pvalue=3.3227420610702333e-69
# powerlaw: statistic=0.2763178880447662, pvalue=1.0110482382010121e-84
# anglit: statistic=0.29467415709424793, pvalue=1.579016022464596e-96
# levy: statistic=0.32490567742981724, pvalue=8.847720692394e-118
# arcsine: statistic=0.33763666052253627, pvalue=2.0485099439783977e-127
# uniform: statistic=0.3741987179487179, pvalue=2.0692501971146356e-157
# rdist: statistic=0.5149486381312224, pvalue=7.086929652583647e-308
# frechet_l: statistic=0.7313603251519716, pvalue=0.0
# levy_l: statistic=0.5385927809594366, pvalue=0.0
# powernorm: statistic=0.9583333333333334, pvalue=0.0
# reciprocal: statistic=1.0, pvalue=0.0
# truncnorm: statistic=1.0, pvalue=0.0
# vonmises: statistic=1.12172818250847e+20, pvalue=0.0
# weibull_max: statistic=0.7313603251519716, pvalue=0.0

# %% [markdown]
# #### It seems the best fitted distribution of Downtime frequency is invgauss distribution, known as inverse Gaussian continuous random variable.
#
# 'https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.invgauss.html'

# %%
sns.distplot(dtf['Downtime'])
